# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
#import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules
from scipy.sparse import csr_matrix

# %% [markdown]
# ### Preprocessing

# %%
# Fetching our data
tData = pd.read_csv("TransactionOrder2.csv")

# %%
tData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7421 entries, 0 to 7420
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   trans_ID                7421 non-null   object
#  1   tr_date                 7421 non-null   object
#  2   item_ID                 7421 non-null   object
#  3   item_description        7421 non-null   object
#  4   item_cat_1_ID           7395 non-null   object
#  5   base_sku                7421 non-null   object
#  6   total_amt               7421 non-null   float64
#  7   Sheet1.billto_ID        7421 non-null   object
#  8   Sheet1.billto_name      6827 non-null   object
#  9   Sheet1.billto_tin       6216 non-null   float64
#  10  Sheet1 (3).description  7395 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 637.9+ KB

# %%
# Only taking the necessary columns
df = tData[["trans_ID", "item_description"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7421 entries, 0 to 7420
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   trans_ID          7421 non-null   object
#  1   item_description  7421 non-null   object
# dtypes: object(2)
# memory usage: 116.1+ KB

# %%
# converting the data to an item basket
# Grouping items by transaction ID, keeping only item descriptions
item_baskets = df.groupby("trans_ID")["item_description"].apply(list)

# Print the item baskets
print(item_baskets)
# Out:
# trans_ID
# 001-04-0000000001                       [RS extra virgin olive oil 1l**12, Local Vinge...
# 001-04-0000000002                       [Fanta pineapple  500ml**, Elsa kolo, Fahm wat...
# 001-04-0000000003                       [coffee 2, Elsa kolo, Basket 25lit, zera roach...
# 001-04-0000000004                       [Tissue paper**48, euro facial tissue, crown d...
# 001-04-0000000005                       [Mara Chick peas 400gm, Mara processed peas 40...
#                                                               ...
# fe6d8b8b-34f6-41b7-b75e-362467627a7b                                              [broom]
# fef1c384-bd0c-463d-8593-76c2047f025b    [Cheese Berta, BUTTER((*5, special top side me...
# ff41967b-b9f7-4dd9-a760-7f5deeb7941e                                              [candy]
# ff42c2be-ff7c-4fbe-aa2b-39441cbea1f5    [vitrac apple juice 1li, vitrac pineapple  jui...
# ffc18917-0022-4387-a4b7-9b7bc5a90ff1                                           [ani pant]
# Name: item_description, Length: 1251, dtype: object

# %% [markdown]
# ### Transforming the item baskets to a boolean matrix

# %%
unique_items = pd.Series(df['item_description'].unique())

# %%
boolean_matrix = pd.DataFrame(False, index=df['trans_ID'].unique(), columns=unique_items)

# %%
for trans_ID, items in item_baskets.items():
    for item in items:
        boolean_matrix.loc[trans_ID, item] = True

# %%
boolean_matrix_sparse = csr_matrix(boolean_matrix)

# %%
print(boolean_matrix.head())
# Out:
#                                       laundry plastic  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91             True
# 273e062f-29dc-48c4-b389-213433718e04            False
# 2a773103-c741-4caf-8702-9822251ad8d2            False
# 6d392ce1-6864-4642-9235-1b39fb96830c            False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a            False
#
#                                       Romoli balsamico vingar 500ml  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                          False
# 273e062f-29dc-48c4-b389-213433718e04                           True
# 2a773103-c741-4caf-8702-9822251ad8d2                          False
# 6d392ce1-6864-4642-9235-1b39fb96830c                          False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                          False
#
#                                       bakerd brown sugar sticks  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                      False
# 273e062f-29dc-48c4-b389-213433718e04                       True
# 2a773103-c741-4caf-8702-9822251ad8d2                      False
# 6d392ce1-6864-4642-9235-1b39fb96830c                      False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                      False
#
#                                       kellerbery corn flakes  500gm  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                          False
# 273e062f-29dc-48c4-b389-213433718e04                           True
# 2a773103-c741-4caf-8702-9822251ad8d2                          False
# 6d392ce1-6864-4642-9235-1b39fb96830c                          False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                          False
#
#                                       RS pitted green olives 467ml  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                         False
# 273e062f-29dc-48c4-b389-213433718e04                          True
# 2a773103-c741-4caf-8702-9822251ad8d2                         False
# 6d392ce1-6864-4642-9235-1b39fb96830c                         False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                         False
#
#                                       bakerd icing sugar powder 500g  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                           False
# 273e062f-29dc-48c4-b389-213433718e04                            True
# 2a773103-c741-4caf-8702-9822251ad8d2                           False
# 6d392ce1-6864-4642-9235-1b39fb96830c                           False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                           False
#
#                                       Flour 50kg  modern mushroom p&s 400g  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91       False                     False
# 273e062f-29dc-48c4-b389-213433718e04        True                      True
# 2a773103-c741-4caf-8702-9822251ad8d2       False                     False
# 6d392ce1-6864-4642-9235-1b39fb96830c       False                     False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a        True                     False
#
#                                       RS pitted black olives 467ml  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                         False
# 273e062f-29dc-48c4-b389-213433718e04                          True
# 2a773103-c741-4caf-8702-9822251ad8d2                         False
# 6d392ce1-6864-4642-9235-1b39fb96830c                         False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                         False
#
#                                       oba spagetti 500g  ...  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91              False  ...
# 273e062f-29dc-48c4-b389-213433718e04               True  ...
# 2a773103-c741-4caf-8702-9822251ad8d2               True  ...
# 6d392ce1-6864-4642-9235-1b39fb96830c              False  ...
# 125d5ab4-4cd1-4913-9063-24b653c00a6a              False  ...
#
#                                       omo fast action 500g(((24  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                      False
# 273e062f-29dc-48c4-b389-213433718e04                      False
# 2a773103-c741-4caf-8702-9822251ad8d2                      False
# 6d392ce1-6864-4642-9235-1b39fb96830c                      False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                      False
#
#                                       Local Vingear-mid  M.T chocolate syrup  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91              False                False
# 273e062f-29dc-48c4-b389-213433718e04              False                False
# 2a773103-c741-4caf-8702-9822251ad8d2              False                False
# 6d392ce1-6864-4642-9235-1b39fb96830c              False                False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a              False                False
#
#                                       M.T peanut butter 510gm**12  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                        False
# 273e062f-29dc-48c4-b389-213433718e04                        False
# 2a773103-c741-4caf-8702-9822251ad8d2                        False
# 6d392ce1-6864-4642-9235-1b39fb96830c                        False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                        False
#
#                                       blue water 0.5 L  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91             False
# 273e062f-29dc-48c4-b389-213433718e04             False
# 2a773103-c741-4caf-8702-9822251ad8d2             False
# 6d392ce1-6864-4642-9235-1b39fb96830c             False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a             False
#
#                                       organa cherry jam 370g  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                   False
# 273e062f-29dc-48c4-b389-213433718e04                   False
# 2a773103-c741-4caf-8702-9822251ad8d2                   False
# 6d392ce1-6864-4642-9235-1b39fb96830c                   False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                   False
#
#                                       geisha rose &honey100g**36  \
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91                       False
# 273e062f-29dc-48c4-b389-213433718e04                       False
# 2a773103-c741-4caf-8702-9822251ad8d2                       False
# 6d392ce1-6864-4642-9235-1b39fb96830c                       False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a                       False
#
#                                       nova water 0.5L  locla egg  geft paper
# 1c3dec63-5d6a-4aaa-a47d-f515180cac91            False      False       False
# 273e062f-29dc-48c4-b389-213433718e04            False      False       False
# 2a773103-c741-4caf-8702-9822251ad8d2            False      False       False
# 6d392ce1-6864-4642-9235-1b39fb96830c            False      False       False
# 125d5ab4-4cd1-4913-9063-24b653c00a6a            False      False       False
#
# [5 rows x 1860 columns]

# %% [markdown]
# ### Applying Apriori

# %%
frequent_itemsets = apriori(boolean_matrix, min_support=0.01, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
print(rules)
# Out:
#                                           antecedents  \
# 0                                        (Flour 50kg)
# 1                           (quaker white oats 500gm)
# 2                            (rosa peanut butter 1kg)
# 3                           (nido powder milk 2500gm)
# 4                                        (BUTTER((*5)
# ..                                                ...
# 90             (farm chicken, farm egg, Cheese Berta)
# 91  (farm chicken, special top side meat, Cheese B...
# 92    (farm egg, special top side meat, Cheese Berta)
# 93                           (farm chicken, farm egg)
# 94                       (farm chicken, Cheese Berta)
#
#                               consequents  antecedent support  \
# 0                            (BUTTER((*5)            0.028777
# 1                      (knorr-all-in-one)            0.031175
# 2               (quaker white oats 500gm)            0.017586
# 3                            (BUTTER((*5)            0.015987
# 4                 (special top side meat)            0.056755
# ..                                    ...                 ...
# 90                (special top side meat)            0.014388
# 91                             (farm egg)            0.019185
# 92                         (farm chicken)            0.017586
# 93  (special top side meat, Cheese Berta)            0.022382
# 94      (farm egg, special top side meat)            0.022382
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 0             0.056755  0.016787    0.583333  10.278169  0.015153    2.263789
# 1             0.032774  0.015987    0.512821  15.647280  0.014965    1.985359
# 2             0.031175  0.011990    0.681818  21.870629  0.011442    3.044878
# 3             0.056755  0.010392    0.650000  11.452817  0.009484    2.694987
# 4             0.108713  0.035971    0.633803   5.830054  0.029801    2.433899
# ..                 ...       ...         ...        ...       ...         ...
# 90            0.108713  0.011191    0.777778   7.154412  0.009627    4.010791
# 91            0.055156  0.011191    0.583333  10.576087  0.010133    2.267626
# 92            0.036771  0.011191    0.636364  17.306324  0.010544    2.648881
# 93            0.036771  0.011191    0.500000  13.597826  0.010368    1.926459
# 94            0.028777  0.011191    0.500000  17.375000  0.010547    1.942446
#
#     zhangs_metric
# 0        0.929453
# 1        0.966213
# 2        0.971359
# 3        0.927514
# 4        0.878324
# ..            ...
# 90       0.872784
# 91       0.923158
# 92       0.959084
# 93       0.947670
# 94       0.964023
#
# [95 rows x 10 columns]

# %%
rules_df = pd.DataFrame(rules)

rules_df = rules_df.drop(['lift','leverage','conviction','zhangs_metric'], axis = 1)

# %%
rules_df.head(50)
# Out:
#                                 antecedents  \
# 0                              (Flour 50kg)
# 1                 (quaker white oats 500gm)
# 2                  (rosa peanut butter 1kg)
# 3                 (nido powder milk 2500gm)
# 4                              (BUTTER((*5)
# 5                            (farm chicken)
# 6                          (niylperch fish)
# 7                            (Cheese Berta)
# 8                                (farm egg)
# 9                 (star lime vim 500ml *12)
# 10                         (niylperch fish)
# 11                             (BUTTER((*5)
# 12                           (Cheese Berta)
# 13                             (BUTTER((*5)
# 14                               (farm egg)
# 15                         (niylperch fish)
# 16                           (farm chicken)
# 17                           (farm chicken)
# 18                         (niylperch fish)
# 19                         (niylperch fish)
# 20                               (farm egg)
# 21                           (Cheese Berta)
# 22                            (difen misir)
# 23               (foster clarks red colour)
# 24                    (foster clark  green)
# 25                 (Herman mayonnaise 32oz)
# 26                  (maggi vegetable stock)
# 27                 (quaker white oats 500g)
# 28                (G.C cornflakes 500gm**8)
# 29                 (BUTTER((*5, Flour 50kg)
# 30               (Cheese Berta, Flour 50kg)
# 31               (farm chicken, BUTTER((*5)
# 32    (farm chicken, special top side meat)
# 33             (niylperch fish, BUTTER((*5)
# 34  (niylperch fish, special top side meat)
# 35      (BUTTER((*5, special top side meat)
# 36               (BUTTER((*5, Cheese Berta)
# 37    (special top side meat, Cheese Berta)
# 38                   (BUTTER((*5, farm egg)
# 39        (farm egg, special top side meat)
# 40    (farm chicken, special top side meat)
# 41           (farm chicken, niylperch fish)
# 42  (niylperch fish, special top side meat)
# 43    (farm chicken, special top side meat)
# 44             (farm chicken, Cheese Berta)
# 45    (special top side meat, Cheese Berta)
# 46                           (farm chicken)
# 47                 (farm chicken, farm egg)
# 48    (farm chicken, special top side meat)
# 49  (niylperch fish, special top side meat)
#
#                               consequents  antecedent support  \
# 0                            (BUTTER((*5)            0.028777
# 1                      (knorr-all-in-one)            0.031175
# 2               (quaker white oats 500gm)            0.017586
# 3                            (BUTTER((*5)            0.015987
# 4                 (special top side meat)            0.056755
# 5                 (special top side meat)            0.036771
# 6                 (special top side meat)            0.026379
# 7                 (special top side meat)            0.055156
# 8                 (special top side meat)            0.055156
# 9                    (smart bleach 800ml)            0.015188
# 10                           (BUTTER((*5)            0.026379
# 11                         (Cheese Berta)            0.056755
# 12                           (BUTTER((*5)            0.055156
# 13                             (farm egg)            0.056755
# 14                           (BUTTER((*5)            0.055156
# 15                         (farm chicken)            0.026379
# 16                         (Cheese Berta)            0.036771
# 17                             (farm egg)            0.036771
# 18                         (Cheese Berta)            0.026379
# 19                             (farm egg)            0.026379
# 20                         (Cheese Berta)            0.055156
# 21                             (farm egg)            0.055156
# 22                           (miser kike)            0.015987
# 23                  (foster clark  green)            0.011191
# 24             (foster clarks red colour)            0.015188
# 25               (safa ketchup 340gm**24)            0.026379
# 26                  (maggi chicken stock)            0.023981
# 27            (G.C white oates 500gm**24)            0.023981
# 28            (G.C white oates 500gm**24)            0.016787
# 29                         (Cheese Berta)            0.016787
# 30                           (BUTTER((*5)            0.012790
# 31                (special top side meat)            0.016787
# 32                           (BUTTER((*5)            0.025580
# 33                (special top side meat)            0.016787
# 34                           (BUTTER((*5)            0.018385
# 35                         (Cheese Berta)            0.035971
# 36                (special top side meat)            0.039169
# 37                           (BUTTER((*5)            0.036771
# 38                (special top side meat)            0.028777
# 39                           (BUTTER((*5)            0.028777
# 40                       (niylperch fish)            0.025580
# 41                (special top side meat)            0.015188
# 42                         (farm chicken)            0.018385
# 43                         (Cheese Berta)            0.025580
# 44                (special top side meat)            0.022382
# 45                         (farm chicken)            0.036771
# 46  (special top side meat, Cheese Berta)            0.036771
# 47                (special top side meat)            0.022382
# 48                             (farm egg)            0.025580
# 49                         (Cheese Berta)            0.018385
#
#     consequent support   support  confidence
# 0             0.056755  0.016787    0.583333
# 1             0.032774  0.015987    0.512821
# 2             0.031175  0.011990    0.681818
# 3             0.056755  0.010392    0.650000
# 4             0.108713  0.035971    0.633803
# 5             0.108713  0.025580    0.695652
# 6             0.108713  0.018385    0.696970
# 7             0.108713  0.036771    0.666667
# 8             0.108713  0.028777    0.521739
# 9             0.027978  0.010392    0.684211
# 10            0.056755  0.016787    0.636364
# 11            0.055156  0.039169    0.690141
# 12            0.056755  0.039169    0.710145
# 13            0.055156  0.028777    0.507042
# 14            0.056755  0.028777    0.521739
# 15            0.036771  0.015188    0.575758
# 16            0.055156  0.022382    0.608696
# 17            0.055156  0.022382    0.608696
# 18            0.055156  0.015987    0.606061
# 19            0.055156  0.013589    0.515152
# 20            0.055156  0.027978    0.507246
# 21            0.055156  0.027978    0.507246
# 22            0.025580  0.011191    0.700000
# 23            0.015188  0.010392    0.928571
# 24            0.011191  0.010392    0.684211
# 25            0.046363  0.014388    0.545455
# 26            0.038369  0.015987    0.666667
# 27            0.025580  0.011990    0.500000
# 28            0.025580  0.010392    0.619048
# 29            0.055156  0.011990    0.714286
# 30            0.056755  0.011990    0.937500
# 31            0.108713  0.013589    0.809524
# 32            0.056755  0.013589    0.531250
# 33            0.108713  0.011990    0.714286
# 34            0.056755  0.011990    0.652174
# 35            0.055156  0.025580    0.711111
# 36            0.108713  0.025580    0.653061
# 37            0.056755  0.025580    0.695652
# 38            0.108713  0.017586    0.611111
# 39            0.056755  0.017586    0.611111
# 40            0.026379  0.012790    0.500000
# 41            0.108713  0.012790    0.842105
# 42            0.036771  0.012790    0.695652
# 43            0.055156  0.019185    0.750000
# 44            0.108713  0.019185    0.857143
# 45            0.036771  0.019185    0.521739
# 46            0.036771  0.019185    0.521739
# 47            0.108713  0.013589    0.607143
# 48            0.055156  0.013589    0.531250
# 49            0.055156  0.012790    0.695652

# %%
pd.set_option('display.max_rows', None)
